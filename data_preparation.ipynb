# %%
import pandas as pd 
import numpy as np
import re

# %%
# read data from excel
df = pd.read_excel('data.xlsx', skiprows=6)

# print the first 5 rows
df.head()
# Out:
#       Deal ID                  Companies  Pending Patent Documents  \
# 0  272893-60T  Wavo (Financial Software)                       NaN
# 1  285153-67T                      Ziwig                       1.0
# 2  285101-92T                   Digifood                       NaN
# 3  285052-87T         Smile Wanted Group                       NaN
# 4  285010-48T                    ekstere                       NaN
#
#    Active Patent Documents  Total Patent Families  Total Patent Documents  \
# 0                      NaN                    NaN                     NaN
# 1                      6.0                    4.0                     7.0
# 2                      NaN                    NaN                     NaN
# 3                      NaN                    NaN                     NaN
# 4                      NaN                    NaN                     NaN
#
#   VC Round Up/Down/Flat  Price per Share  % Acquired Post Valuation Status  \
# 0                   NaN              NaN         NaN                   NaN
# 1                   NaN              NaN         NaN                   NaN
# 2                   NaN              NaN         NaN                   NaN
# 3                   NaN              NaN         NaN                   NaN
# 4                   NaN              NaN         NaN                   NaN
#
#    ...   VC Round Deal Size Post Valuation       Deal Type  \
# 0  ...  1st Round      3.63            NaN  Early Stage VC
# 1  ...  3rd Round       NaN            NaN  Later Stage VC
# 2  ...  3rd Round       NaN            NaN  Later Stage VC
# 3  ...  1st Round     10.37            NaN  Later Stage VC
# 4  ...  1st Round      2.49            NaN  Later Stage VC
#
#                                             Keywords  Deal Date  \
# 0  capital needs, commercial finance, financial t... 2025-02-17
# 1  diagnostic platform, endometriosis treatment, ... 2025-02-14
# 2  digital food menu, digital food ordering, food... 2025-02-13
# 3  brand design, campaign support, campaign work,... 2025-02-13
# 4  eco-friendly products online, electric bicycle... 2025-02-12
#
#                    Primary Industry Code  \
# 0                     Financial Software
# 1           Discovery Tools (Healthcare)
# 2  Other Restaurants, Hotels and Leisure
# 3   Media and Information Services (B2B)
# 4                             Automotive
#
#                                            Verticals  \
# 0  Artificial Intelligence & Machine Learning, Fi...
# 1  Artificial Intelligence & Machine Learning, Li...
# 2                              FoodTech, Mobile, TMT
# 3                             AdTech, Marketing Tech
# 4                                         E-Commerce
#
#                    HQ Location View Company Online
# 0                 Lyon, France                 NaN
# 1                 Lyon, France                 NaN
# 2               Vanves, France                 NaN
# 3                Paris, France                 NaN
# 4  Vélizy-Villacoublay, France                 NaN
#
# [5 rows x 34 columns]

# %%
# Build the regex dynamically
ignore_pattern = '|'.join(['Private\s+Equity', 'Financial\s+Services', 'Electrical\s+Equipment'])
pattern = rf'\((?:[A-Z]{2,4}:\s*[A-Z0-9.]+)\)|\((?![A-Z]{2,4}:\s*[A-Z0-9.]+)(?!{ignore_pattern})([A-Za-zÀ-ÖØ-öø-ÿ-]+(?:\s+[A-Za-zÀ-ÖØ-öø-ÿ-]+)+)\)'

# Compile regex for better performance
compiled_regex = re.compile(pattern)

# %%
# Select the columns investors
investors = df['Investors']

# Function to extract partner names
def extract_partners(text):
    matches = re.findall(pattern, text)
    # Flatten the list and remove empty strings
    cleaned_matches = [match for sublist in matches for match in sublist if match]
    return ", ".join(cleaned_matches) if cleaned_matches else None
    

# Apply function to create 'partners' column only to the first 5 rows
df["Partners"] = investors.apply(extract_partners)

# %%
df['Partners'].head(20)
# Out:
# 0                                           Tony Parker
# 1                                                  None
# 2                                                  None
# 3                        Ménelé Chesnot, Benjamin Cohen
# 4                                                  None
# 5                                        Arnaud Vincent
# 6                                          Bruno Akpaka
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10    Herve Silbert, Anne-Sophie Saint-Martin, Rapha...
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                         Marcell Vollmer, Mario Götze
# 15                                                 None
# 16                                                 None
# 17    Charles Gorintin, Marie Brayer, Jean-Louis Qué...
# 18                                                 None
# 19                                                 None
# Name: Partners, dtype: object

# %%
from collections import Counter

# Function to filter two-word names
def get_two_word_names(partners_list):
    two_word_names = []
    for names in partners_list:
        if names:  # Ensure it's not None
            for name in names.split(", "):  # Handle multiple names
                if len(name.split()) == 2:  # Check if it has exactly two words
                    two_word_names.append(name)
    return two_word_names

# Extract all partner names from the column
all_partners = df["Partners"].dropna().tolist()

# Get only two-word names
two_word_names = get_two_word_names(all_partners)

# Count occurrences
name_counts = Counter(two_word_names)

# Convert to DataFrame for visualization
df_name_counts = pd.DataFrame(name_counts.items(), columns=["Two-Word Name", "Frequency"]).sort_values(by="Frequency", ascending=False)

# Display the frequency table
df_name_counts.head(50)
# Out:
#                 Two-Word Name  Frequency
# 438               Xavier Niel         99
# 2213          Guillaume Aubin         41
# 250           Thibaud Elziere         41
# 914           Joséphine Marie         33
# 842    Jean-David Chamboredon         28
# 38         Philippe Collombel         25
# 1425            Chahra Louafi         24
# 1218           Romain Lavault         24
# 788         Rodolphe Menegaux         24
# 2290           Marc Simoncini         22
# 2070  Jacques-Antoine Granjon         22
# 3055          Jérémie Berrebi         21
# 45             Thierry Laugel         20
# 295                Celia Hart         20
# 811          Vincent Deltrieu         19
# 1133       Benjamin Wainstain         19
# 469        Stéphanie Hospital         19
# 755          Guillaume Meulle         18
# 2289          Dominique Vidal         18
# 256           Renaud Guillerm         18
# 1759           Nicolas Boulay         18
# 79              Jérôme Guéret         18
# 1356              Valéry Huot         18
# 369              Claire Houry         18
# 519           Jean-Marc Bally         17
# 766            Cyril Bertrand         17
# 1866    Jean-Marc Patouillaud         17
# 1147         François Meteyer         16
# 738    Charles-Antoine Morand         16
# 2109       Guillaume Hemmerle         16
# 904            Bruno Guicheux         16
# 1559          Olivier Mathiot         15
# 885            Thibaut Roulon         15
# 335            Antoine Freysz         15
# 1556         Guillaume Dupont         15
# 700            Xavier Lazarus         15
# 418           Cyril Vermeulen         15
# 312         Antoine Papiernik         15
# 1600         Oleg Tscheltzoff         15
# 33        Clémentine Cazenave         15
# 1347          Catherine Boule         15
# 314        Samantha Jérusalmy         14
# 784           Stéphane Pesqué         14
# 911       Bertrand Distinguin         14
# 905         Charles Beigbeder         14
# 1149             Raffi Kamber         14
# 467          Xavier Lorphelin         14
# 643           Reza Malekzadeh         14
# 163             Alison Imbert         14
# 2451       Charles Letourneur         13

# %%
# Drop rows where 'partners' column is NaN
df = df.dropna(subset=['Partners'])

# Verify the result
df.head()
# Out:
#        Deal ID                   Companies  Pending Patent Documents  \
# 0   272893-60T   Wavo (Financial Software)                       NaN
# 3   285052-87T          Smile Wanted Group                       NaN
# 5   284916-61T                    Germitec                      14.0
# 6   279892-63T            ToumAI Analytics                       NaN
# 10  284336-56T  Reev (Therapeutic Devices)                       1.0
#
#     Active Patent Documents  Total Patent Families  Total Patent Documents  \
# 0                       NaN                    NaN                     NaN
# 3                       NaN                    NaN                     NaN
# 5                      78.0                   18.0                   103.0
# 6                       NaN                    NaN                     NaN
# 10                      NaN                    1.0                     1.0
#
#    VC Round Up/Down/Flat  Price per Share  % Acquired Post Valuation Status  \
# 0                    NaN              NaN         NaN                   NaN
# 3                    NaN              NaN         NaN                   NaN
# 5                    NaN              NaN         NaN                   NaN
# 6                    NaN              NaN         NaN                   NaN
# 10                   NaN              NaN         NaN                   NaN
#
#     ... Deal Size Post Valuation       Deal Type  \
# 0   ...      3.63            NaN  Early Stage VC
# 3   ...     10.37            NaN  Later Stage VC
# 5   ...     30.05            NaN  Later Stage VC
# 6   ...      1.04            NaN  Early Stage VC
# 10  ...      9.20            NaN  Early Stage VC
#
#                                              Keywords  Deal Date  \
# 0   capital needs, commercial finance, financial t... 2025-02-17
# 3   brand design, campaign support, campaign work,... 2025-02-13
# 5   disinfectants care, disinfection product, disi... 2025-02-12
# 6   customer relationship management, multichannel... 2025-02-10
# 10  healthcare service, muscle strengthening tools... 2025-02-06
#
#                    Primary Industry Code  \
# 0                     Financial Software
# 3   Media and Information Services (B2B)
# 5                   Monitoring Equipment
# 6         Business/Productivity Software
# 10                   Therapeutic Devices
#
#                                             Verticals       HQ Location  \
# 0   Artificial Intelligence & Machine Learning, Fi...      Lyon, France
# 3                              AdTech, Marketing Tech     Paris, France
# 5                                          HealthTech  Bordeaux, France
# 6    Artificial Intelligence & Machine Learning, SaaS    Cannes, France
# 10                                         HealthTech  Toulouse, France
#
#    View Company Online                                           Partners
# 0                  NaN                                        Tony Parker
# 3                  NaN                     Ménelé Chesnot, Benjamin Cohen
# 5                  NaN                                     Arnaud Vincent
# 6                  NaN                                       Bruno Akpaka
# 10                 NaN  Herve Silbert, Anne-Sophie Saint-Martin, Rapha...
#
# [5 rows x 35 columns]

# %%
# Save the results to a new csv file
df.to_csv('data.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
