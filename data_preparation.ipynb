# %%
import pandas as pd 
import numpy as np
import re

# %%
# read data from excel
df = pd.read_excel('data_2.xlsx')

# print the first 5 rows
df.head()
# Out:
#       Deal ID Company ID Company Name  \
# 0  249733-63T  464342-95     Flowdesk
# 1  249733-63T  464342-95     Flowdesk
# 2  249733-63T  464342-95     Flowdesk
# 3  249733-63T  464342-95     Flowdesk
# 4  249733-63T  464342-95     Flowdesk
#
#                                          Description Investor ID  \
# 0  Developer of a compliant trading and liquidity...    10768-06
# 1  Developer of a compliant trading and liquidity...    58004-02
# 2  Developer of a compliant trading and liquidity...   187980-13
# 3  Developer of a compliant trading and liquidity...   523414-99
# 4  Developer of a compliant trading and liquidity...    11180-08
#
#        Investor Name          Investor Website  Investor Status  \
# 0          BlackRock         www.blackrock.com  Active Investor
# 1          Bpifrance          www.bpifrance.fr  Active Investor
# 2  Cathay Innovation  www.cathayinnovation.com  Active Investor
# 3    Delphi Ventures         delphiventures.io  Active Investor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21446 entries, 0 to 21445
# Data columns (total 62 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Deal ID                                     21446 non-null  object
#  1   Company ID                                  21446 non-null  object
#  2   Company Name                                21446 non-null  object
#  3   Description                                 21446 non-null  object
#  4   Investor ID                                 21446 non-null  object
#  5   Investor Name                               21446 non-null  object
#  6   Investor Website                            17504 non-null  object
#  7   Investor Status                             21446 non-null  object
#  8   Primary Investor Type                       21446 non-null  object
# ...

# %%
# # Build the regex dynamically
# ignore_pattern = '|'.join(['Private\s+Equity', 'Financial\s+Services', 'Electrical\s+Equipment'])
# pattern = rf'\((?:[A-Z]{2,4}:\s*[A-Z0-9.]+)\)|\((?![A-Z]{2,4}:\s*[A-Z0-9.]+)(?!{ignore_pattern})([A-Za-zÀ-ÖØ-öø-ÿ-]+(?:\s+[A-Za-zÀ-ÖØ-öø-ÿ-]+)+)\)'

# # Compile regex for better performance
# compiled_regex = re.compile(pattern)

# %%
# # Select the columns investors
# investors = df['Investors']

# # Function to extract partner names
# def extract_partners(text):
#     matches = re.findall(pattern, text)
#     # Flatten the list and remove empty strings
#     cleaned_matches = [match for sublist in matches for match in sublist if match]
#     return ", ".join(cleaned_matches) if cleaned_matches else None
    

# # Apply function to create 'partners' column only to the first 5 rows
# df["Partners"] = investors.apply(extract_partners)

# %%
from collections import Counter

# Function to filter two-word names
def get_two_word_names(partners_list):
    two_word_names = []
    for names in partners_list:
        if names:  # Ensure it's not None
            for name in names.split(", "):  # Handle multiple names
                if len(name.split()) == 2:  # Check if it has exactly two words
                    two_word_names.append(name)
    return two_word_names

# Extract all partner names from the column
all_partners = df["Lead Partner"].dropna().tolist()

# Get only two-word names
two_word_names = get_two_word_names(all_partners)

# Count occurrences
name_counts = Counter(two_word_names)

# Convert to DataFrame for visualization
df_name_counts = pd.DataFrame(name_counts.items(), columns=["Two-Word Name", "Frequency"]).sort_values(by="Frequency", ascending=False)

# Display the frequency table
df_name_counts.head(50)
# Out:
#                 Two-Word Name  Frequency
# 397               Xavier Niel         81
# 237           Thibaud Elziere         39
# 858           Joséphine Marie         30
# 2075          Guillaume Aubin         24
# 1153           Romain Lavault         22
# 787    Jean-David Chamboredon         21
# 59             Thierry Laugel         19
# 1940  Jacques-Antoine Granjon         19
# 424        Stéphanie Hospital         19
# 242           Renaud Guillerm         18
# 1345            Chahra Louafi         17
# 2841          Jérémie Berrebi         16
# 2148          Dominique Vidal         16
# 276                Celia Hart         16
# 760          Vincent Deltrieu         16
# 293         Antoine Papiernik         15
# 81              Jérôme Guéret         15
# 50        Clémentine Cazenave         15
# 1823       Philippe Collombel         15
# 162             Alison Imbert         14
# 315            Antoine Freysz         14
# 2149           Marc Simoncini         14
# ...

# %%
# Drop rows where 'partners' column is NaN
df = df.dropna(subset=['Lead Partner'])

# Verify the result
df.head()
# Out:
#        Deal ID Company ID               Company Name  \
# 2   249733-63T  464342-95                   Flowdesk
# 4   249733-63T  464342-95                   Flowdesk
# 5   249733-63T  464342-95                   Flowdesk
# 30  272893-60T  530537-68  Wavo (Financial Software)
# 32  285052-87T  512410-51         Smile Wanted Group
#
#                                           Description Investor ID  \
# 2   Developer of a compliant trading and liquidity...   187980-13
# 4   Developer of a compliant trading and liquidity...    11180-08
# 5   Developer of a compliant trading and liquidity...    51189-94
# 30  Developer of a financial platform designed to ...   434507-50
# 32  Operator of a digital advertising marketplace ...    58004-02
#
#         Investor Name          Investor Website  Investor Status  \
# 2   Cathay Innovation  www.cathayinnovation.com  Active Investor
# 4             Eurazeo           www.eurazeo.com  Active Investor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6436 entries, 2 to 21442
# Data columns (total 62 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Deal ID                                     6436 non-null   object
#  1   Company ID                                  6436 non-null   object
#  2   Company Name                                6436 non-null   object
#  3   Description                                 6436 non-null   object
#  4   Investor ID                                 6436 non-null   object
#  5   Investor Name                               6436 non-null   object
#  6   Investor Website                            4040 non-null   object
#  7   Investor Status                             6436 non-null   object
#  8   Primary Investor Type                       6436 non-null   object
#  9   Other Investor Types                        2677 non-null   object
# ...

# %%
def most_relevant_sector_per_investor(df):
    # Group by investor and sector, count investments
    sector_counts = df.groupby(['Lead Partner', 'Primary Industry Sector']).size().reset_index(name='Investment Count')

    # Sort by investor and investment count (descending), then keep the top sector for each investor
    top_sectors = sector_counts.sort_values(['Lead Partner', 'Investment Count'], ascending=[True, False])
    
    most_relevant = top_sectors.drop_duplicates(subset='Lead Partner', keep='first')

    
    print(f"Dimensions of the resulting DataFrame: {most_relevant.shape}")
    print(f"Dimensions of the original DataFrame: {df.shape}")
    
    return most_relevant.reset_index(drop=True)

# %%
def most_relevant_sector_per_investor_search(df, name):
    # Group by investor and sector, count investments
    sector_counts = df.groupby(['Lead Partner', 'Primary Industry Sector']).size().reset_index(name='Investment Count')

    # Sort by investor and investment count (descending), then keep the top sector for each investor
    top_sectors = sector_counts.sort_values(['Lead Partner', 'Investment Count'], ascending=[True, False])
    
    top_sectors = top_sectors[top_sectors['Lead Partner'] == name]

    return top_sectors

# %%
# Apply the function to the dataset
relevant_sectors = most_relevant_sector_per_investor(df)
# Out:
# Dimensions of the resulting DataFrame: (3357, 3)
# Dimensions of the original DataFrame: (6436, 62)

# %%
relevant_sectors.shape
# Out:
# (3357, 3)

# %%
# First, create a mapping from investor to their most relevant sector
investor_sector_map = relevant_sectors.set_index('Lead Partner')['Primary Industry Sector'].to_dict()

# Add the new column to the original DataFrame
df['Primary Investor Sector'] = df['Lead Partner'].map(investor_sector_map)

# %%
df.shape
# Out:
# (6436, 63)

# %%
# Filter rows where Lead Partner is either Benoist Grossman or Julien-David Nitchel
filtered_df = df[df['Lead Partner'].isin(['Benoist Grossmann', 'Julien-David Nitlech'])]

# Display the filtered rows
filtered_df.shape
# Out:
# (15, 63)

# %%
# Filter the data only by VC and BA

# For this Benoist Grossman and Julien-David Nitchel were not appearing in the dataset as they were not in the list of investors

# df = df[df["Primary Investor Type"].isin(["Venture Capital","Angel (individual)"])]
# df.head()

# %%
# Save the results to a new csv file
df.to_csv('data.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6436 entries, 2 to 21442
# Data columns (total 63 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Deal ID                                     6436 non-null   object
#  1   Company ID                                  6436 non-null   object
#  2   Company Name                                6436 non-null   object
#  3   Description                                 6436 non-null   object
#  4   Investor ID                                 6436 non-null   object
#  5   Investor Name                               6436 non-null   object
#  6   Investor Website                            4040 non-null   object
#  7   Investor Status                             6436 non-null   object
#  8   Primary Investor Type                       6436 non-null   object
#  9   Other Investor Types                        2677 non-null   object
# ...

# %%
# Calculate the threshold for 80% null values
threshold = len(df) * 0.8

# Drop columns with more than 80% null values
df = df.dropna(thresh=threshold, axis=1)

df.head()
# Out:
#        Deal ID Company ID               Company Name  \
# 2   249733-63T  464342-95                   Flowdesk
# 4   249733-63T  464342-95                   Flowdesk
# 5   249733-63T  464342-95                   Flowdesk
# 30  272893-60T  530537-68  Wavo (Financial Software)
# 32  285052-87T  512410-51         Smile Wanted Group
#
#                                           Description Investor ID  \
# 2   Developer of a compliant trading and liquidity...   187980-13
# 4   Developer of a compliant trading and liquidity...    11180-08
# 5   Developer of a compliant trading and liquidity...    51189-94
# 30  Developer of a financial platform designed to ...   434507-50
# 32  Operator of a digital advertising marketplace ...    58004-02
#
#         Investor Name  Investor Status  Primary Investor Type  \
# 2   Cathay Innovation  Active Investor        Venture Capital
# 4             Eurazeo  Active Investor              PE/Buyout
# ...

# %%
df['Deal Date'] = pd.to_datetime(df['Deal Date'])
min_date = df['Deal Date'].min()
min_date
# Out:
# Timestamp('2010-01-01 00:00:00')

# %%
# Save the cleaned data to a new CSV file
df.to_csv('cleaned_data.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6436 entries, 2 to 21442
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Deal ID                         6436 non-null   object
#  1   Company ID                      6436 non-null   object
#  2   Company Name                    6436 non-null   object
#  3   Description                     6436 non-null   object
#  4   Investor ID                     6436 non-null   object
#  5   Investor Name                   6436 non-null   object
#  6   Investor Status                 6436 non-null   object
#  7   Primary Investor Type           6436 non-null   object
#  8   Preferred Industries            5218 non-null   object
#  9   Investor HQ                     5416 non-null   object
#  10  Lead Partner                    6436 non-null   object
#  11  Lead/Sole                       6436 non-null   object
# ...
